# %%
import dagshub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import dagshub
#
# ModuleNotFoundError: No module named 'dagshub'
